# %%
import sys
sys.path.append("/scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages")
sys.path.append("/scratch/group/csce435-f23/thicket")
from glob import glob

import matplotlib.pyplot as plt
import pandas as pd

import thicket as th

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# %%
tk = th.Thicket.from_caliperreader(glob("mpitest/*.cali"))

# %%
tk.dataframe
# Out:
#                                                               nid  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              16622357      1
#                                                   51098878      1
#                                                   74805164      1
#                                                   169442883     1
#                                                   247919279     1
#                                                   292235984     1
#                                                   318777879     1
#                                                   421856043     1
#                                                   428304482     1
#                                                   477870351     1
#                                                   479143806     1
#                                                   516486688     1
# ...

# %%
tk.metadata
# Out:
#            cali.caliper.version  mpi.world.size  \
# profile
# 16622357             2.11.0-dev             256
# 51098878             2.11.0-dev            1024
# 68682582             2.11.0-dev              16
# 74805164             2.11.0-dev             256
# 85883744             2.11.0-dev               8
# 95918667             2.11.0-dev               2
# 102437652            2.11.0-dev              16
# 104638031            2.11.0-dev              16
# 134585409            2.11.0-dev              32
# 169442883            2.11.0-dev            1024
# 181336226            2.11.0-dev               4
# 187521856            2.11.0-dev               4
# 202668048            2.11.0-dev              32
# 210468165            2.11.0-dev               8
# 230827205            2.11.0-dev            1024
# 236270196            2.11.0-dev              16
# 247713992            2.11.0-dev              16
# 247919279            2.11.0-dev              64
# ...

# %%
byInput = tk.groupby("InputType")
# Out:
# 4  thickets created...
# {0: <thicket.thicket.Thicket object at 0x2b57484a8550>, 1: <thicket.thicket.Thicket object at 0x2b57438b8d60>, 2: <thicket.thicket.Thicket object at 0x2b574374c4f0>, 3: <thicket.thicket.Thicket object at 0x2b57435acb50>}

# %%
print(byInput.keys)
# Out:
# <built-in method keys of dict object at 0x2b574934cf80>

# %%
RandbySize = byInput[3].groupby("InputSize")
# RandbySize.drop_duplicates()
ctk = th.Thicket.concat_thickets(
    thickets=list(RandbySize.values()),
    headers=list(RandbySize.keys()),
    axis="columns",
    metadata_key="num_procs"
)
# Out:
# 7  thickets created...
# {65536: <thicket.thicket.Thicket object at 0x2b574bfedcd0>, 262144: <thicket.thicket.Thicket object at 0x2b574bc85a90>, 1048576: <thicket.thicket.Thicket object at 0x2b574ba92c70>, 4194304: <thicket.thicket.Thicket object at 0x2b574bb44550>, 16777216: <thicket.thicket.Thicket object at 0x2b574ba92820>, 67108864: <thicket.thicket.Thicket object at 0x2b574c1c2820>, 268435456: <thicket.thicket.Thicket object at 0x2b574c1c2c10>}

# %%
ctk.dataframe
# Out:
#                                                             65536  \
#                                                               nid
# node                                              num_procs
# {'name': 'main', 'type': 'function'}              2             1
#                                                   4             1
#                                                   8             1
#                                                   16            1
#                                                   32            1
#                                                   64            1
#                                                   128           1
#                                                   256           1
#                                                   512           1
#                                                   1024          1
# {'name': 'comm', 'type': 'function'}              2             6
# ...

# %%
# Drop unwanted columns
ctk.dataframe = ctk.dataframe.reset_index().drop([(65536, "spot.channel"), (268435456, "nid"), (67108864, "spot.channel"), (268435456, "spot.channel"), (67108864, "nid"), (262144, "nid"),(262144, "spot.channel"), (65536, "nid"),(1048576, "spot.channel"), (1048576, "nid"),(4194304, "spot.channel"), (4194304, "nid"), (16777216, "spot.channel"),(16777216, "nid"),(65536, "Min time/rank"), (67108864, "Min time/rank"), (268435456, "Min time/rank"),(65536, "Max time/rank"), (67108864, "Max time/rank"), (268435456, "Max time/rank"),(65536, "Total time"), (67108864, "Total time"), (268435456, "Total time"),(262144, "Min time/rank"),(262144, "Max time/rank"),(262144, "Total time"),(1048576, "Min time/rank"),(4194304, "Min time/rank"),(4194304, "Max time/rank"),(4194304, "Total time"),(1048576, "Max time/rank"),(1048576, "Total time"),(16777216, "Min time/rank"),(16777216, "Max time/rank"),(16777216, "Total time")], axis=1)
#65536 262144 1048576 4194304 16777216 67108864 268435456
# ctk.dataframe = ctk.dataframe.reset_index().drop([(65536, "Min GPU time/rank"), (268435456, "Min GPU time/rank"), (67108864, "Min GPU time/rank"),(65536, "Max GPU time/rank"), (67108864, "Max GPU time/rank"), (268435456, "Max GPU time/rank"),(65536, "Avg GPU time/rank"), (268435456, "Avg GPU time/rank"), (67108864, "Avg GPU time/rank"),(65536, "Total GPU time"), (268435456, "Total GPU time"), (67108864, "Total GPU time"),(262144, "Min GPU time/rank"),(262144, "Max GPU time/rank"),(262144, "Avg GPU time/rank"),(262144, "Total GPU time"),(1048576, "Min GPU time/rank"),(4194304, "Min GPU time/rank"),(4194304, "Max GPU time/rank"),(4194304, "Avg GPU time/rank"),(4194304, "Total GPU time"),(1048576, "Max GPU time/rank"),(1048576, "Avg GPU time/rank"),(1048576, "Total GPU time"),(16777216, "Min GPU time/rank"),(16777216, "Max GPU time/rank"),(16777216, "Avg GPU time/rank"),(16777216, "Total GPU time")], axis=1)
# Rename index to remove tuple
ctk.dataframe = ctk.dataframe.rename({("name", ""): "name", ("num_procs", ""): "num_procs"}).set_index(["name", "num_procs"])
# Drop "time" label as it is redundant
# ctk.dataframe.columns = ctk.dataframe.columns.droplevel(1)

# %%
# ctk.dataframe = ctk.dataframe.drop('index',axis=1)
ctk.dataframe
# Out:
#                                                                           node  \
#
# name              num_procs
# main              2                       {'name': 'main', 'type': 'function'}
#                   4                       {'name': 'main', 'type': 'function'}
#                   8                       {'name': 'main', 'type': 'function'}
#                   16                      {'name': 'main', 'type': 'function'}
#                   32                      {'name': 'main', 'type': 'function'}
#                   64                      {'name': 'main', 'type': 'function'}
#                   128                     {'name': 'main', 'type': 'function'}
#                   256                     {'name': 'main', 'type': 'function'}
#                   512                     {'name': 'main', 'type': 'function'}
#                   1024                    {'name': 'main', 'type': 'function'}
# ...

# %%
# Define common variables
print(list(ctk.dataframe.columns))
function_names = set(ctk.dataframe.index.get_level_values("name"))
num_procs = sorted(list(set(ctk.dataframe.index.get_level_values("num_procs"))))
# n_vals = sorted(ctk.dataframe.columns.tolist())
n_vals = [[65536], [262144], [1048576], [4194304], [16777216]]
# Out:
# [('node', ''), (65536, 'Avg time/rank'), (65536, 'Variance time/rank'), (262144, 'Avg time/rank'), (262144, 'Variance time/rank'), (1048576, 'Avg time/rank'), (1048576, 'Variance time/rank'), (4194304, 'Avg time/rank'), (4194304, 'Variance time/rank'), (16777216, 'Avg time/rank'), (16777216, 'Variance time/rank'), (67108864, 'Avg time/rank'), (67108864, 'Variance time/rank'), (268435456, 'Avg time/rank'), (268435456, 'Variance time/rank')]

# %% [markdown]
# ## Plot

# %%
def plot_pandas(df, title, xlabel, ylabel, loglog):
    plot = df.plot(kind="line", 
        marker='o', 
        title=title, 
        xlabel=xlabel,
        ylabel=ylabel, 
        grid=True,
        loglog=loglog
    )
    return plot

# %%
def plot_mpl(df, title, xlabel, ylabel):
    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1)
    ax.plot(
        df,
        marker='o',
    )
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.legend(matrix_sizes)
    plt.grid(True)
    plt.yscale("log", base=10)
    plt.xscale("log", base=2)
    plt.xticks(threads)
    plt.show()
    return fig, ax

# %% [markdown]
# ## time

# %%
print(ctk.dataframe.loc['comp',1048576])
# Out:
#            Avg time/rank  Variance time/rank
# num_procs
# 2               0.118725            0.000002
# 4               0.059048            0.000047
# 8               0.029895            0.000034
# 16              0.015648            0.000027
# 32              0.007532            0.000016
# 64              0.003726            0.000009
# 128             0.001878            0.000005
# 256             0.000941            0.000002
# 512             0.000484            0.000001
# 1024            0.000256            0.000001
# <ipython-input-46-5312e498f886>:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   print(ctk.dataframe.loc['comp',1048576])

# %%
ctk.dataframe.loc['main'].plot(kind="line",
        marker='o',
        title="Strong Scaling",
        xlabel="Threads",
        ylabel="Time (seconds)",
        loglog=True,)
vals = []
for i in range(len(n_vals)):
    vals.append(n_vals[i][0])
plt.legend([65536, 262144, 1048576, 4194304, 16777216, 67108864, 268435456])

# %%
thread_l=[]

time=[]
times=[]
l=[]
size=65536
threads=4
base=ctk.dataframe.loc['main',65536]['Avg time/rank'][4]
while threads<=512:
    time.append(base/ctk.dataframe.loc['main',size]['Avg time/rank'][threads])
    thread_l.append(threads)
    threads*=4
    size*=4
l.append(thread_l)
times.append(time)
time=[]
thread_l=[]
size=65536
threads=2
#base=ctk.dataframe.loc['main',65536]['Avg time/rank'][2]
while threads<=512:
    time.append(base/ctk.dataframe.loc['main',size]['Avg time/rank'][threads])
    thread_l.append(threads)
    threads*=4
    size*=4
times.append(time)
l.append(thread_l)

size=262144
threads=4
time=[]
thread_l=[]
#base=ctk.dataframe.loc['main',262144]['Avg time/rank'][4]
while threads<=512:
    time.append(base/ctk.dataframe.loc['main',size]['Avg time/rank'][threads])
    thread_l.append(threads)
    threads*=4
    size*=4
l.append(thread_l)
times.append(time)
size=262144
threads=2
time=[]
thread_l=[]
#base=ctk.dataframe.loc['main',262144]['Avg time/rank'][2]
while threads<=512:
    time.append(base/ctk.dataframe.loc['main',size]['Avg time/rank'][threads])
    thread_l.append(threads)
    threads*=4
    size*=4
l.append(thread_l)
times.append(time)

print(l)
print(times)
for i in range(len(times)):
    plt.plot(l[i],times[i])
plt.legend(["2^14 e/t", "2^15 e/t","2^16 e/t","2^17 e/t"])
plt.xscale("log", base=2)
plt.xlabel("Threads")
plt.ylabel("Speedup")
plt.title("Weak Scaling")
plt.show()
# Out:
# <ipython-input-70-4276eb567b4a>:8: PerformanceWarning: indexing past lexsort depth may impact performance.
#   base=ctk.dataframe.loc['main',65536]['Avg time/rank'][4]
# <ipython-input-70-4276eb567b4a>:10: PerformanceWarning: indexing past lexsort depth may impact performance.
#   time.append(base/ctk.dataframe.loc['main',size]['Avg time/rank'][threads])
# <ipython-input-70-4276eb567b4a>:22: PerformanceWarning: indexing past lexsort depth may impact performance.
#   time.append(base/ctk.dataframe.loc['main',size]['Avg time/rank'][threads])
# <ipython-input-70-4276eb567b4a>:35: PerformanceWarning: indexing past lexsort depth may impact performance.
#   time.append(base/ctk.dataframe.loc['main',size]['Avg time/rank'][threads])
# <ipython-input-70-4276eb567b4a>:47: PerformanceWarning: indexing past lexsort depth may impact performance.
#   time.append(base/ctk.dataframe.loc['main',size]['Avg time/rank'][threads])
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-a84b15f79f6c> in <module>
#       5         ylabel="Time (seconds)",
#       6         loglog=True,)
# ----> 7 plot.show()
#
# NameError: name 'plot' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-86-78f46eed8560> in <module>
#       2
#       3 for i in range(3):
# ----> 4     cpu = ctk.dataframe.loc['main', idx[((small_subset_size[i], types[0]),
#       5                                                (small_subset_size[i], types[1]),
#       6                                               (small_subset_size[i], types[2]),
#
# NameError: name 'idx' is not defined
